# %%
import folium

#print(folium.__version__)

# %%
map_SiteInvestigation = folium.Map(
    location=[-43.52, 172.5860],
    zoom_start=12,
    #tiles='Stamen Terrain'
    tiles='OpenStreetMap'
)

folium.Marker([-43.522168, 172.582185], 
              popup='Rutherford building/University of Canterbury').add_to(map_SiteInvestigation)

folium.CircleMarker([-43.5215, 172.6261], radius=50,
                    popup='Test', color='#3186cc',
                    fill_color='#3186cc').add_to(map_SiteInvestigation)

folium.LatLngPopup().add_to(map_SiteInvestigation)

#folium.Marker([45.3311, -121.7113], popup='Timberline Lodge', icon=folium.Icon()).add_to(mt_hood)
map_SiteInvestigation
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
